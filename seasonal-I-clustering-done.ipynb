# %%
import pandas as pd
import sys  
sys.path.insert(0, 'D:\\Master of IT\\Data Mining Bendigo\\clustering\\Seasonal_clustering')
import utilities

# %%
file = 'bgo_I.csv'

# %%
df = pd.read_csv(file)

# %%
df.head()
# Out:
#   cust_type  read_date channel  interval_1  interval_2  interval_3  \
# 0         I  1/10/2019       E      1.7500      1.8625      1.8375
# 1         I  2/10/2019       E      1.9625      1.8125      1.9250
# 2         I  3/10/2019       E      2.1875      2.1375      2.2000
# 3         I  4/10/2019       E      2.0625      1.8750      2.0625
# 4         I  5/10/2019       E      2.1500      2.0500      1.2500
#
#    interval_4  interval_5  interval_6  interval_7  ...  interval_39  \
# 0      2.0500      2.2125      0.7625      1.0000  ...        2.600
# 1      2.0625      1.8750      1.8000      1.7250  ...        2.075
# 2      1.2000      1.1750      0.8000      1.0375  ...        2.450
# 3      1.8250      1.5875      0.7875      0.9750  ...        1.125
# 4      0.9375      0.9625      0.6125      1.0125  ...        2.200
#
#    interval_40  interval_41  interval_42  interval_43  interval_44  \
# 0       2.2625       2.0250       2.2375       2.3250       2.7375
# ...

# %%
summer = utilities.seasonDf(df, 'Summer')
autumn = utilities.seasonDf(df, 'Autumn')
winter = utilities.seasonDf(df, 'Winter')
spring = utilities.seasonDf(df, 'Spring')

# %%
utilities.plotInertia(15, summer)
# Out:
# Total size:8365

# %%
summerLabel3 = utilities.generateLabel(3, summer, 'I in Summer')
# Out:
# Cluster size:723
# Cluster size:91
# Cluster size:7551

# %%
summerLabel2 = utilities.generateLabel(2, summer, 'I in Summer')
# Out:
# Cluster size:8274
# Cluster size:91

# %%
utilities.confirmConcat(summer, summerLabel2, 'I\\I_Summer.csv')

# %%
utilities.plotInertia(15, autumn)
# Out:
# Total size:8463

# %%
autumnLabel2 = utilities.generateLabel(2, autumn, 'I in Autumn')
# Out:
# Cluster size:8371
# Cluster size:92

# %%
autumnLabel3 = utilities.generateLabel(3, autumn, 'I in Autumn')
# Out:
# Cluster size:7655
# Cluster size:92
# Cluster size:716

# %%
utilities.confirmConcat(autumn, autumnLabel2, 'I\\I_Autumn.csv')

# %%
utilities.plotInertia(15, winter)
# Out:
# Total size:8284

# %%
winterLabel2 = utilities.generateLabel(2, winter, 'I in Winter')
# Out:
# Cluster size:8191
# Cluster size:93

# %%
winterLabel3 = utilities.generateLabel(3, winter, 'I in Winter')
# Out:
# Cluster size:7529
# Cluster size:662
# Cluster size:93

# %%
utilities.confirmConcat(winter, winterLabel3, 'I\\I_Winter.csv')

# %%
utilities.plotInertia(15, spring)
# Out:
# Total size:8216

# %%
springLabel2 = utilities.generateLabel(2, spring, 'I in Spring')
# Out:
# Cluster size:8127
# Cluster size:89

# %%
springLabel3 = utilities.generateLabel(3, spring, 'I in Spring')
# Out:
# Cluster size:88
# Cluster size:8111
# Cluster size:17

# %%
utilities.confirmConcat(spring,springLabel2, 'I\\I_Spring.csv')
