# %%
import pandas as pd
import sys  
sys.path.insert(0, 'D:\\Master of IT\\Data Mining Bendigo\\clustering\\Seasonal_clustering')
import utilities

# %%
file = 'bgo_C.csv'

# %%
df = pd.read_csv(file)

# %%
df.head()
# Out:
#   cust_type  read_date channel  interval_1  interval_2  interval_3  \
# 0         C  1/10/2019       E       0.721       0.724       0.714
# 1         C  2/10/2019       E       0.744       0.735       0.741
# 2         C  3/10/2019       E       0.750       0.750       0.749
# 3         C  4/10/2019       E       0.257       0.248       0.258
# 4         C  5/10/2019       E       0.215       0.225       0.222
#
#    interval_4  interval_5  interval_6  interval_7  ...  interval_39  \
# 0       0.731       0.729       0.719       0.728  ...        0.758
# 1       0.747       0.752       0.743       0.761  ...        0.749
# 2       0.758       0.760       0.754       0.765  ...        0.257
# 3       0.257       0.255       0.248       0.264  ...        0.225
# 4       0.225       0.224       0.216       0.222  ...        0.228
#
#    interval_40  interval_41  interval_42  interval_43  interval_44  \
# 0        0.759        0.759        0.746        0.750        0.752
# ...

# %%
summer = utilities.seasonDf(df, 'Summer')
autumn = utilities.seasonDf(df, 'Autumn')
winter = utilities.seasonDf(df, 'Winter')
spring = utilities.seasonDf(df, 'Spring')

# %%
utilities.plotInertia(15, summer)
# Out:
# Total size:44338

# %%
summerLabel3 = utilities.generateLabel(3, summer, 'C in Summer')
# Out:
# Cluster size:43201
# Cluster size:920
# Cluster size:217

# %%
summerLabel2 = utilities.generateLabel(2, summer, 'C in Summer')
# Out:
# Cluster size:43586
# Cluster size:752

# %%
utilities.confirmConcat(summer, summerLabel3, 'C\\C_Summer.csv')

# %%
utilities.plotInertia(15, autumn)
# Out:
# Total size:44920

# %%
autumnLabel3 = utilities.generateLabel(3, autumn, 'C in Autumn')
# Out:
# Cluster size:43951
# Cluster size:780
# Cluster size:189

# %%
autumnLabel2 = utilities.generateLabel(2, autumn, 'C in Autumn')
# Out:
# Cluster size:44234
# Cluster size:686

# %%
utilities.confirmConcat(autumn, autumnLabel2, 'C\\C_Autumn.csv')

# %%
utilities.plotInertia(15, winter)
# Out:
# Total size:43627

# %%
winterLabel3 = utilities.generateLabel(3, winter, 'C in Winter')
# Out:
# Cluster size:42490
# Cluster size:184
# Cluster size:953

# %%
winterLabel2 = utilities.generateLabel(2, winter, 'C in Winter')
# Out:
# Cluster size:42780
# Cluster size:847

# %%
utilities.confirmConcat(winter, winterLabel2, 'C\\C_Winter.csv')

# %%
utilities.plotInertia(15, spring)
# Out:
# Total size:43948

# %%
springLabel3 = utilities.generateLabel(3, spring, 'C in Spring')
# Out:
# Cluster size:42847
# Cluster size:894
# Cluster size:207

# %%
springLabel2 = utilities.generateLabel(2, spring, 'C in Spring')
# Out:
# Cluster size:43145
# Cluster size:803

# %%
utilities.confirmConcat(spring,springLabel2, 'C\\C_Spring.csv')
